# %% [markdown]
# # Bangkok Neighborhood Analysis along BTS Sukhumvit Line

# %% [markdown]
# ## Background
# Bangkok is one of the mega cities where 10 million people reside. The city occupies 1,568.7 square kilometres and consists of 50 districts with different lifestyles and neighborhoods. The main transportation in Bangkok is by roads which can accommodate only 1.5 million vehicles whereas the city has 9.7 million automobiles and motorbikes combined. This overcapacity has led to multiple issues such as traffic jam, high fuel consumption and air pollution. The average person would spend 207 extra hours per year driving in the rush hours in Bangkok.
#
# The Bangkok Mass Transit System, commonly known as the BTS is an elevated rapid transit system in Bangkok has opened the first line called “Green Line” which consists of 1.Silom Line and 2.Sukhumvit Line in late 1999 to ease the mentioned traffic jam issues on the roads. Currently, this Green Line support around 700 thousand people daily and became the major mass transit system in Bangkok.
#
# In this study, the scope of study will be the neighborhood along “BTS Sukhumvit Line” which consists of 32 stations as depicted below:
#
# <img src=https://upload.wikimedia.org/wikipedia/commons/thumb/0/0d/BTS_Sukhumvit.jpg/300px-BTS_Sukhumvit.jpg>
#
# The main reason to pick this Sukhumvit line is due to its importance in term of people served per day compared to Silom Line. Also, this line also passed “Asok Intersection” which marked as one of the central business districts in Bangkok.

# %% [markdown]
# ## Business Problem
# This study will try to identify the suitable neighborhoods along BTS Sukhumvit Line which lower living expenses and shorten commute time to work. The results of this study would benefit many stakeholders such as expatriates and multinational companies who need to identify the suitable location for their employees to reside. Also, it will be good for real estate developers to explore new potential areas to develop the new projects based on the model of this analysis.
#
# For this study, I will assume that the target work location is at “Asok Station” in the central business district and residential neighborhood would be around stations along BTS Sukhumvit Line. The preferred commute time from/to work location would be within 30 mins which can be indirectly transform to the distance of 12 stations away.

# %% [markdown]
# ## Data used to solve problem
# 1. Location of BTS Sukhumvit Line: Due to unavailability of preformatted data source and the limit number of stations on Sukhumvit Line, I have extracted the location of each station from Wikipedia and put into CSV format as the below:

# %%
import pandas as pd
Sukhumvit_Stations = pd.read_csv('Sukhumvit_Line.csv')
Sukhumvit_Stations.head()
# Out:
#    Sequence       Station Name   Latitude   Longitude
# 0         1  Ha Yaek Lat Phrao  13.816552  100.562012
# 1         2            Mo Chit  13.802583  100.553833
# 2         3       Saphan Khwai  13.793800  100.549731
# 3         4                Ari  13.779703  100.544642
# 4         5          Sanam Pao  13.772622  100.542092

# %% [markdown]
# - Sequence: Sequence identification of each station along Sukhumvit Line
# - Station Name: Name of each station
# - Latitude and Longitude: Coordinates of each station

# %% [markdown]
# 2. Foursquare Venues: Using Foursquare’s Place API to retrieve details of venues, categories and price.

# %% [markdown]
# # Methodology
# ## Explore the location of stations along BTS Sukhumvit Line

# %%
# !conda install -c conda-forge geopy --yes

# Import used libraries
from sklearn.cluster import KMeans
from geopy.geocoders import Nominatim
import folium
import numpy as np
import requests
import matplotlib.cm as cm
import matplotlib.colors as colors
# Out:
# Solving environment: done
#
#
# ==> WARNING: A newer version of conda exists. <==
#   current version: 4.5.11
#   latest version: 4.8.2
#
# Please update conda by running
#
#     $ conda update -n base -c defaults conda
#
#
#
# ## Package Plan ##
#
#   environment location: /home/jupyterlab/conda/envs/python
#
#   added / updated specs:
#     - geopy
#
#
# The following packages will be downloaded:
#
#     package                    |            build
#     ---------------------------|-----------------
#     certifi-2019.11.28         |           py36_0         149 KB  conda-forge
#     scikit-learn-0.20.1        |   py36h22eb022_0         5.7 MB
#     liblapack-3.8.0            |      11_openblas          10 KB  conda-forge
#     numpy-1.18.1               |   py36h95a1406_0         5.2 MB  conda-forge
#     liblapacke-3.8.0           |      11_openblas          10 KB  conda-forge
#     geographiclib-1.50         |             py_0          34 KB  conda-forge
#     libopenblas-0.3.6          |       h5a2b251_2         7.7 MB
#     scipy-1.4.1                |   py36h921218d_0        18.9 MB  conda-forge
#     geopy-1.21.0               |             py_0          58 KB  conda-forge
#     libcblas-3.8.0             |      11_openblas          10 KB  conda-forge
#     libblas-3.8.0              |      11_openblas          10 KB  conda-forge
#     blas-2.11                  |         openblas          10 KB  conda-forge
#     ------------------------------------------------------------
#                                            Total:        37.9 MB
#
# The following NEW packages will be INSTALLED:
#
#     geographiclib: 1.50-py_0                              conda-forge
#     geopy:         1.21.0-py_0                            conda-forge
#     libblas:       3.8.0-11_openblas                      conda-forge
#     libcblas:      3.8.0-11_openblas                      conda-forge
#     liblapack:     3.8.0-11_openblas                      conda-forge
#     liblapacke:    3.8.0-11_openblas                      conda-forge
#     libopenblas:   0.3.6-h5a2b251_2
#
# The following packages will be UPDATED:
#
#     blas:          1.1-openblas                           conda-forge --> 2.11-openblas         conda-forge
#     certifi:       2019.9.11-py36_0                       conda-forge --> 2019.11.28-py36_0     conda-forge
#     numpy:         1.16.2-py36_blas_openblash1522bff_0    conda-forge [blas_openblas] --> 1.18.1-py36h95a1406_0 conda-forge
#     scipy:         1.2.1-py36_blas_openblash1522bff_0     conda-forge [blas_openblas] --> 1.4.1-py36h921218d_0  conda-forge
#
# The following packages will be DOWNGRADED:
#
#     scikit-learn:  0.20.1-py36_blas_openblashebff5e3_1200 conda-forge [blas_openblas] --> 0.20.1-py36h22eb022_0
#
#
# Downloading and Extracting Packages
# certifi-2019.11.28   | 149 KB    | ##################################### | 100%
# scikit-learn-0.20.1  | 5.7 MB    | ##################################### | 100%
# liblapack-3.8.0      | 10 KB     | ##################################### | 100%
# numpy-1.18.1         | 5.2 MB    | ##################################### | 100%
# liblapacke-3.8.0     | 10 KB     | ##################################### | 100%
# geographiclib-1.50   | 34 KB     | ##################################### | 100%
# libopenblas-0.3.6    | 7.7 MB    | ##################################### | 100%
# scipy-1.4.1          | 18.9 MB   | ##################################### | 100%
# geopy-1.21.0         | 58 KB     | ##################################### | 100%
# libcblas-3.8.0       | 10 KB     | ##################################### | 100%
# libblas-3.8.0        | 10 KB     | ##################################### | 100%
# blas-2.11            | 10 KB     | ##################################### | 100%
# Preparing transaction: done
# Verifying transaction: done
# Executing transaction: done

# %%
# Getting location of Bangkok
address = 'Bangkok, Thailand'

geolocator = Nominatim(user_agent="safari")
location = geolocator.geocode(address)
latitude = location.latitude
longitude = location.longitude
print('The geograpical coordinate of Bangkok are {}, {}.'.format(latitude, longitude))
# Out:
# The geograpical coordinate of Bangkok are 13.7542529, 100.493087.

# %%
# Create map
map_stations = folium.Map(location=[latitude, longitude], zoom_start=11)

# Add markers to the map
for lat, lon, poi in zip(Sukhumvit_Stations['Latitude'], Sukhumvit_Stations['Longitude'], Sukhumvit_Stations['Station Name']):
    label = folium.Popup(str(poi), parse_html=True)
    folium.CircleMarker(
        [lat, lon],
        radius=5,
        popup=label,
        color='red',
        fill=True,
        fill_color='red',
        fill_opacity=0.7).add_to(map_stations)
       
map_stations
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# ## Filter out stations beyond 12 stations away from “Asok Station”

# %%
# Find sequence of Asok Station
Seq_Asok = Sukhumvit_Stations.loc[Sukhumvit_Stations['Station Name']=='Asok']['Sequence'].values[0]
# Create distance from Asok Station (Unit is number of station away from Asok Station)
Sukhumvit_Stations['Distance'] = abs(Sukhumvit_Stations['Sequence'] - Seq_Asok)
# Filter only stations within 12 stations away from Asok Station
Selected_Stations = Sukhumvit_Stations.loc[Sukhumvit_Stations['Distance']<=12]

Selected_Stations
# Out:
#     Sequence       Station Name   Latitude   Longitude  Distance
# 0          1  Ha Yaek Lat Phrao  13.816552  100.562012        12
# 1          2            Mo Chit  13.802583  100.553833        11
# 2          3       Saphan Khwai  13.793800  100.549731        10
# 3          4                Ari  13.779703  100.544642         9
# 4          5          Sanam Pao  13.772622  100.542092         8
# 5          6   Victory Monument  13.762744  100.537086         7
# 6          7         Phaya Thai  13.756942  100.533844         6
# 7          8        Ratchathewi  13.751875  100.531575         5
# 8          9               Siam  13.745619  100.534228         4
# 9         10           Chit Lom  13.744108  100.543097         3
# 10        11        Phloen Chit  13.743081  100.549019         2
# 11        12               Nana  13.740603  100.555397         1
# 12        13               Asok  13.737033  100.560419         0
# 13        14        Phrom Phong  13.730439  100.569731         1
# 14        15           Thong Lo  13.724244  100.578558         2
# 15        16            Ekkamai  13.719558  100.585175         3
# 16        17       Phra Khanong  13.715194  100.591283         4
# 17        18             On Nut  13.705611  100.601083         5
# 18        19          Bang Chak  13.696751  100.605349         6
# 19        20         Punnawithi  13.688919  100.609211         7
# 20        21           Udom Suk  13.680317  100.609658         8
# 21        22            Bang Na  13.668146  100.604703         9
# 22        23            Bearing  13.659336  100.601050        10
# 23        24            Samrong  13.647363  100.596153        11
# 24        25            Pu Chao  13.637280  100.592000        12

# %%
# Show these stations on the map
# Create map
map_stations = folium.Map(location=[latitude, longitude], zoom_start=11)

# Add markers to the map
markers_colors = []
for lat, lon, poi in zip(Selected_Stations['Latitude'], Selected_Stations['Longitude'], Selected_Stations['Station Name']):
    label = folium.Popup(str(poi), parse_html=False)
    folium.CircleMarker(
        [lat, lon],
        radius=5,
        popup=label,
        color='green',
        fill=True,
        fill_color='green',
        fill_opacity=0.7).add_to(map_stations)
       
map_stations
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# # Explore venues within 1,000 meters around stations via FourSquare API.

# %%
# Define FourSquare Credentials and Version
CLIENT_ID = 'TLKNSN5KHGP4O2HU4K1LJZQAFD14TD0A2OFN0T5PVLGDQ1PY' # your Foursquare ID
CLIENT_SECRET = 'KKCA5MSHIOPJEDZGH35K1JCI2P0WP2AIEPTOZQDQLZMPWZ2D' # your Foursquare Secret
VERSION = '20180605' # Foursquare API version

# %%
# Create GET Request
LIMIT = 100
radius = 1000

# Get venues around each station
def getNearbyVenues(names, latitudes, longitudes, radius=radius):
    
    venues_list=[]
    for name, lat, lng in zip(names, latitudes, longitudes):
        print(name)
            
        # create the API request URL
        url = 'https://api.foursquare.com/v2/venues/explore?&client_id={}&client_secret={}&v={}&ll={},{}&radius={}&limit={}'.format(
            CLIENT_ID, 
            CLIENT_SECRET, 
            VERSION, 
            lat, 
            lng, 
            radius, 
            LIMIT)
            
        # make the GET request
        results = requests.get(url).json()["response"]['groups'][0]['items']
        
        # return only relevant information for each nearby venue
        venues_list.append([(
            name, 
            lat, 
            lng,
            v['venue']['id'],
            v['venue']['name'], 
            v['venue']['location']['lat'], 
            v['venue']['location']['lng'],  
            v['venue']['categories'][0]['name']) for v in results])

    nearby_venues = pd.DataFrame([item for venue_list in venues_list for item in venue_list])
    nearby_venues.columns = ['Station Name', 
                  'Station Latitude', 
                  'Station Longitude',
                  'Venue ID',
                  'Venue', 
                  'Venue Latitude', 
                  'Venue Longitude', 
                  'Venue Category']
    
    return(nearby_venues)

# Get vanues for all select stations
station_venues = getNearbyVenues(names=Selected_Stations['Station Name'],
                                   latitudes=Selected_Stations['Latitude'],
                                   longitudes=Selected_Stations['Longitude']
                                  )
# Out:
# Ha Yaek Lat Phrao
# Mo Chit
# Saphan Khwai
# Ari
# Sanam Pao
# Victory Monument
# Phaya Thai
# Ratchathewi
# Siam
# Chit Lom
# Phloen Chit
# Nana
# Asok
# Phrom Phong
# Thong Lo
# Ekkamai
# Phra Khanong
# On Nut
# Bang Chak
# Punnawithi
# Udom Suk
# Bang Na
# Bearing
# Samrong
# Pu Chao

# %% [markdown]
# ### Explore venues results return from FourSquare

# %%
# Check venues size and venue count by Station Name
print('Total records:',station_venues.shape[0])
print('Uniques categories:', len(station_venues['Venue Category'].unique()))
station_venues.groupby('Station Name').count()
# Out:
# Total records: 2155
# Uniques categories: 200
#                    Station Latitude  Station Longitude  Venue  Venue Latitude  \
# Station Name
# Ari                             100                100    100             100
# Asok                            100                100    100             100
# Bang Chak                        44                 44     44              44
# Bang Na                          52                 52     52              52
# Bearing                          38                 38     38              38
# Chit Lom                        100                100    100             100
# Ekkamai                         100                100    100             100
# Ha Yaek Lat Phrao               100                100    100             100
# Mo Chit                         100                100    100             100
# Nana                            100                100    100             100
# On Nut                           89                 89     89              89
# Phaya Thai                      100                100    100             100
# Phloen Chit                     100                100    100             100
# Phra Khanong                    100                100    100             100
# Phrom Phong                     100                100    100             100
# Pu Chao                          34                 34     34              34
# Punnawithi                       83                 83     83              83
# Ratchathewi                     100                100    100             100
# Samrong                          44                 44     44              44
# Sanam Pao                       100                100    100             100
# Saphan Khwai                     88                 88     88              88
# Siam                            100                100    100             100
# Thong Lo                        100                100    100             100
# Udom Suk                         83                 83     83              83
# Victory Monument                100                100    100             100
#
#                    Venue Longitude  Venue Category
# Station Name
# Ari                            100             100
# Asok                           100             100
# Bang Chak                       44              44
# Bang Na                         52              52
# Bearing                         38              38
# Chit Lom                       100             100
# Ekkamai                        100             100
# Ha Yaek Lat Phrao              100             100
# Mo Chit                        100             100
# Nana                           100             100
# On Nut                          89              89
# Phaya Thai                     100             100
# Phloen Chit                    100             100
# Phra Khanong                   100             100
# Phrom Phong                    100             100
# Pu Chao                         34              34
# Punnawithi                      83              83
# Ratchathewi                    100             100
# Samrong                         44              44
# Sanam Pao                      100             100
# Saphan Khwai                    88              88
# Siam                           100             100
# Thong Lo                       100             100
# Udom Suk                        83              83
# Victory Monument               100             100

# %% [markdown]
# ## Analyze each neighborhoods around stations

# %%
# one hot encoding
station_onehot = pd.get_dummies(station_venues[['Venue Category']], prefix="", prefix_sep="")

# add neighborhood column back to dataframe
station_onehot['Station Name'] = station_venues['Station Name'] 

# Move Station Name column to the first column
fixed_columns = [station_onehot.columns[-1]] + list(station_onehot.columns[:-1])
station_onehot = station_onehot[fixed_columns]
station_grouped = station_onehot.groupby('Station Name').mean().reset_index()
station_grouped
# Out:
#          Station Name  Accessories Store  American Restaurant  Aquarium  \
# 0                 Ari               0.00                 0.00      0.00
# 1                Asok               0.00                 0.00      0.00
# 2           Bang Chak               0.00                 0.00      0.00
# 3             Bang Na               0.00                 0.00      0.00
# 4             Bearing               0.00                 0.00      0.00
# 5            Chit Lom               0.00                 0.00      0.00
# 6             Ekkamai               0.00                 0.00      0.00
# 7   Ha Yaek Lat Phrao               0.00                 0.00      0.00
# 8             Mo Chit               0.00                 0.00      0.00
# 9                Nana               0.00                 0.00      0.00
T.reset_index()
    temp.columns = ['venue','freq']
    temp = temp.iloc[1:]
    temp['freq'] = temp['freq'].astype(float)
    temp = temp.round({'freq': 2})
    print(temp.sort_values('freq', ascending=False).reset_index(drop=True).head(num_top_venues))
    print('\n')
# Out:
# ----Ari----
#                  venue  freq
# 0      Thai Restaurant  0.11
# 1                 Café  0.08
# 2          Coffee Shop  0.08
# 3         Noodle House  0.06
# 4                  Bar  0.05
# 5     Sushi Restaurant  0.05
# 6   Som Tum Restaurant  0.04
# 7  Japanese Restaurant  0.04
# 8           Restaurant  0.04
# 9            BBQ Joint  0.03
#
#
# ----Asok----
#                venue  freq
# 0              Hotel  0.15
# 1  Korean Restaurant  0.09
# 2        Coffee Shop  0.07
# 3                Spa  0.06
# 4    Thai Restaurant  0.06
# 5       Burger Joint  0.03
# 6         Restaurant  0.03
# 7          Hotel Bar  0.03
# 8               Café  0.02
# 9        Pizza Place  0.02
#
#
# ----Bang Chak----
#                  venue  freq
# 0    Convenience Store  0.16
# 1         Noodle House  0.14
# 2          Coffee Shop  0.09
# 3                Hotel  0.07
# 4      Thai Restaurant  0.07
# 5   Chinese Restaurant  0.07
# 6   Italian Restaurant  0.05
# 7        Train Station  0.05
# 8  Japanese Restaurant  0.02
# 9             Boutique  0.02
#
#
# ----Bang Na----
#                   venue  freq
# 0           Coffee Shop  0.17
# 1     Convenience Store  0.08
# 2          Noodle House  0.04
# 3  Fast Food Restaurant  0.04
# 4       Thai Restaurant  0.04
# 5         Train Station  0.04
# 6            Steakhouse  0.02
# 7              Bus Line  0.02
# 8           Bus Station  0.02
# 9         Shopping Mall  0.02
#
#
# ----Bearing----
#                venue  freq
# 0  Convenience Store  0.13
# 1        Coffee Shop  0.11
# 2       Noodle House  0.11
# 3               Café  0.05
# 4           Bus Stop  0.05
# 5             Market  0.05
# 6   Asian Restaurant  0.05
# 7    Thai Restaurant  0.05
# 8             Bakery  0.05
# 9         Steakhouse  0.05
#
#
# ----Chit Lom----
#                 venue  freq
# 0               Hotel  0.16
# 1         Coffee Shop  0.07
# 2     Thai Restaurant  0.05
# 3                 Spa  0.04
# 4      Ice Cream Shop  0.03
# 5          Restaurant  0.03
# 6    Department Store  0.03
# 7  Italian Restaurant  0.03
# 8  Chinese Restaurant  0.03
# 9              Buffet  0.02
#
#
# ----Ekkamai----
#                   venue  freq
# 0   Japanese Restaurant  0.11
# 1           Coffee Shop  0.10
# 2       Thai Restaurant  0.09
# 3                  Café  0.07
# 4          Noodle House  0.04
# 5          Dessert Shop  0.04
# 6  Gym / Fitness Center  0.03
# 7      Ramen Restaurant  0.03
# 8                 Hotel  0.03
# 9             Hotel Bar  0.02
#
#
# ----Ha Yaek Lat Phrao----
#                   venue  freq
# 0           Coffee Shop  0.08
# 1                   Bar  0.07
# 2       Thai Restaurant  0.06
# 3   Japanese Restaurant  0.04
# 4          Dessert Shop  0.04
# 5        Ice Cream Shop  0.04
# 6     Korean Restaurant  0.04
# 7                Bakery  0.03
# 8        Clothing Store  0.03
# 9  Fast Food Restaurant  0.02
#
#
# ----Mo Chit----
#                 venue  freq
# 0         Coffee Shop  0.10
# 1     Thai Restaurant  0.08
# 2   Convenience Store  0.07
# 3                Café  0.05
# 4        Noodle House  0.05
# 5  Som Tum Restaurant  0.04
# 6  Seafood Restaurant  0.04
# 7       Shopping Mall  0.04
# 8                 Bar  0.03
# 9                Park  0.03
#
#
# ----Nana----
#                  venue  freq
# 0                Hotel  0.19
# 1    Korean Restaurant  0.09
# 2            Hotel Bar  0.05
# 3    Indian Restaurant  0.05
# 4  Japanese Restaurant  0.04
# 5          Coffee Shop  0.04
# 6                  Bar  0.03
# 7                  Spa  0.03
# 8                 Café  0.03
# 9   Italian Restaurant  0.03
#
#
# ----On Nut----
#                                       venue  freq
# 0                         Convenience Store  0.15
# 1                                     Hotel  0.08
# 2                               Coffee Shop  0.07
# 3                        Italian Restaurant  0.04
# 4                      Fast Food Restaurant  0.04
# 5                            Ice Cream Shop  0.03
# 6                              Noodle House  0.03
# 7  Residential Building (Apartment / Condo)  0.03
# 8                       Japanese Restaurant  0.02
# 9                        Chinese Restaurant  0.02
#
#
# ----Phaya Thai----
#                  venue  freq
# 0                Hotel  0.13
# 1         Noodle House  0.07
# 2               Hostel  0.06
# 3          Coffee Shop  0.06
# 4           Steakhouse  0.06
# 5                 Café  0.05
# 6           Restaurant  0.04
# 7   Som Tum Restaurant  0.03
# 8  Japanese Restaurant  0.02
# 9      Thai Restaurant  0.02
#
#
# ----Phloen Chit----
#                  venue  freq
# 0                Hotel  0.16
# 1          Coffee Shop  0.08
# 2                 Café  0.07
# 3      Thai Restaurant  0.06
# 4           Restaurant  0.05
# 5            Hotel Bar  0.04
# 6  Japanese Restaurant  0.03
# 7    French Restaurant  0.03
# 8   Italian Restaurant  0.03
# 9               Buffet  0.02
#
#
# ----Phra Khanong----
#                   venue  freq
# 0           Coffee Shop  0.13
# 1   Japanese Restaurant  0.11
# 2     Convenience Store  0.09
# 3                Bakery  0.04
# 4          Noodle House  0.04
# 5  Gym / Fitness Center  0.04
# 6      Ramen Restaurant  0.03
# 7                  Café  0.03
# 8           Supermarket  0.02
# 9       Thai Restaurant  0.02
#
#
# ----Phrom Phong----
#                  venue  freq
# 0  Japanese Restaurant  0.09
# 1                 Café  0.07
# 2                Hotel  0.06
# 3          Coffee Shop  0.05
# 4      Thai Restaurant  0.05
# 5        Shopping Mall  0.04
# 6          Supermarket  0.04
# 7           Restaurant  0.03
# 8     Ramen Restaurant  0.03
# 9                  Spa  0.03
#
#
# ----Pu Chao----
#                   venue  freq
# 0     Convenience Store  0.15
# 1          Noodle House  0.12
# 2            Food Truck  0.06
# 3          Intersection  0.06
# 4             BBQ Joint  0.06
# 5           Coffee Shop  0.03
# 6           Bus Station  0.03
# 7              Bus Stop  0.03
# 8  Gym / Fitness Center  0.03
# 9         Grocery Store  0.03
#
#
# ----Punnawithi----
#                   venue  freq
# 0     Convenience Store  0.13
# 1       Thai Restaurant  0.08
# 2          Noodle House  0.07
# 3           Coffee Shop  0.07
# 4  Fast Food Restaurant  0.07
# 5        Ice Cream Shop  0.04
# 6                  Café  0.04
# 7                Bakery  0.04
# 8    Chinese Restaurant  0.02
# 9         Train Station  0.02
#
#
# ----Ratchathewi----
#                venue  freq
# 0              Hotel  0.10
# 1        Coffee Shop  0.08
# 2             Hostel  0.08
# 3       Dessert Shop  0.05
# 4             Bakery  0.04
# 5               Café  0.03
# 6         Restaurant  0.03
# 7  Korean Restaurant  0.03
# 8      Shopping Mall  0.03
# 9           Tea Room  0.02
#
#
# ----Samrong----
#                     venue  freq
# 0            Noodle House  0.07
# 1       Convenience Store  0.07
# 2    Fast Food Restaurant  0.07
# 3                  Bakery  0.05
# 4                  Market  0.05
# 5       Hotpot Restaurant  0.05
# 6        Ramen Restaurant  0.05
# 7  Shabu-Shabu Restaurant  0.02
# 8                    Café  0.02
# 9      Chinese Restaurant  0.02
#
#
# ----Sanam Pao----
#               venue  freq
# 0       Coffee Shop  0.10
# 1      Noodle House  0.10
# 2   Thai Restaurant  0.07
# 3  Sushi Restaurant  0.06
# 4               Bar  0.05
# 5        Restaurant  0.04
# 6            Bakery  0.04
# 7             Hotel  0.03
# 8              Café  0.03
# 9         BBQ Joint  0.03
#
#
# ----Saphan Khwai----
#                            venue  freq
# 0                Thai Restaurant  0.11
# 1                    Coffee Shop  0.09
# 2                   Noodle House  0.08
# 3             Som Tum Restaurant  0.08
# 4                           Café  0.06
# 5              Convenience Store  0.05
# 6                      BBQ Joint  0.02
# 7                   Dessert Shop  0.02
# 8                            Bar  0.02
# 9  Vegetarian / Vegan Restaurant  0.02
#
#
# ----Siam----
#                venue  freq
# 0        Coffee Shop  0.10
# 1       Dessert Shop  0.06
# 2               Café  0.05
# 3             Bakery  0.05
# 4      Shopping Mall  0.04
# 5    Thai Restaurant  0.04
# 6     Cosmetics Shop  0.03
# 7      Movie Theater  0.03
# 8  Korean Restaurant  0.03
# 9        Salad Place  0.03
#
#
# ----Thong Lo----
#                  venue  freq
# 0      Thai Restaurant  0.16
# 1  Japanese Restaurant  0.07
# 2          Coffee Shop  0.07
# 3                Hotel  0.06
# 4                 Café  0.06
# 5            BBQ Joint  0.06
# 6                  Bar  0.05
# 7         Noodle House  0.04
# 8            Hotel Bar  0.03
# 9                  Spa  0.03
#
#
# ----Udom Suk----
#                   venue  freq
# 0     Convenience Store  0.11
# 1       Thai Restaurant  0.11
# 2          Noodle House  0.06
# 3  Fast Food Restaurant  0.05
# 4           Coffee Shop  0.04
# 5                  Café  0.04
# 6                   Bar  0.04
# 7             BBQ Joint  0.02
# 8                 Hotel  0.02
# 9            Donut Shop  0.02
#
#
# ----Victory Monument----
#                venue  freq
# 0              Hotel  0.11
# 1       Noodle House  0.10
# 2        Coffee Shop  0.08
# 3               Café  0.07
# 4         Steakhouse  0.05
# 5    Thai Restaurant  0.04
# 6  Convenience Store  0.03
# 7             Hostel  0.03
# 8         Restaurant  0.02
# 9         Food Court  0.02

# %%
# Arrange top 10 categories into Dataframe
def return_most_common_venues(row, num_top_venues):
    row_categories = row.iloc[1:]
    row_categories_sorted = row_categories.sort_values(ascending=False)

    return row_categories_sorted.index.values[0:num_top_venues]

# Create columns according to number of top venues
indicators = ['st', 'nd', 'rd']
columns = ['Station Name']
for ind in np.arange(num_top_venues):
    try:
        columns.append('{}{} Most Common Venue'.format(ind+1, indicators[ind]))
    except:
        columns.append('{}th Most Common Venue'.format(ind+1))

# Create a new dataframe
station_sorted = pd.DataFrame(columns=columns)
station_sorted['Station Name'] = station_grouped['Station Name']

for ind in np.arange(station_grouped.shape[0]):
    station_sorted.iloc[ind,1:] = return_most_common_venues(station_grouped.iloc[ind,:], num_top_venues)

station_sorted.head()
# Out:
#   Station Name 1st Most Common Venue 2nd Most Common Venue  \
# 0          Ari       Thai Restaurant           Coffee Shop
# 1         Asok                 Hotel     Korean Restaurant
# 2    Bang Chak     Convenience Store          Noodle House
# 3      Bang Na           Coffee Shop     Convenience Store
# 4      Bearing     Convenience Store          Noodle House
#
#   3rd Most Common Venue 4th Most Common Venue 5th Most Common Venue  \
# 0                  Café          Noodle House                   Bar
# 1           Coffee Shop       Thai Restaurant                   Spa
# 2           Coffee Shop    Chinese Restaurant                 Hotel
# 3  Fast Food Restaurant          Noodle House         Train Station
# 4           Coffee Shop       Thai Restaurant                  Café
#
#   6th Most Common Venue 7th Most Common Venue 8th Most Common Venue  \
# 0      Sushi Restaurant    Som Tum Restaurant            Restaurant
# 1            Restaurant             Hotel Bar          Burger Joint
# 2       Thai Restaurant    Italian Restaurant         Train Station
# 3       Thai Restaurant     Hotpot Restaurant           Music Venue
# 4            Steakhouse                Market              Bus Stop
#
#   9th Most Common Venue 10th Most Common Venue
# 0   Japanese Restaurant              BBQ Joint
# 1                  Café              BBQ Joint
# 2                   Spa                 Market
# 3               Stadium     Golf Driving Range
# 4      Asian Restaurant                 Bakery

# %% [markdown]
# ## Clustering Neighborhood around each station

# %%
# Set number of clusters
kclusters = 5

station_grouped_clustering = station_grouped.drop('Station Name', 1)

# Run k-means clustering
kmeans = KMeans(n_clusters=kclusters, random_state=0).fit(station_grouped_clustering)

# Add clustering labels
station_sorted.insert(0, 'Cluster Labels', kmeans.labels_)

# Merge Dataframes
station_merged = Selected_Stations.join(station_sorted.set_index('Station Name'), on='Station Name')

station_merged
# Out:
#     Sequence       Station Name   Latitude   Longitude  Distance  \
# 0          1  Ha Yaek Lat Phrao  13.816552  100.562012        12
# 1          2            Mo Chit  13.802583  100.553833        11
# 2          3       Saphan Khwai  13.793800  100.549731        10
# 3          4                Ari  13.779703  100.544642         9
# 4          5          Sanam Pao  13.772622  100.542092         8
# 5          6   Victory Monument  13.762744  100.537086         7
# 6          7         Phaya Thai  13.756942  100.533844         6
# 7          8        Ratchathewi  13.751875  100.531575         5
# 8          9               Siam  13.745619  100.534228         4
# 9         10           Chit Lom  13.744108  100.543097         3
# 10        11        Phloen Chit  13.743081  100.549019         2
# 11        12               Nana  13.740603  100.555397         1
# 12        13               Asok  13.737033  100.560419         0
# 13        14        Phrom Phong  13.730439  100.569731         1
# 14        15           Thong Lo  13.724244  100.578558         2
# 15        16            Ekkamai  13.719558  100.585175         3
# 16        17       Phra Khanong  13.715194  100.591283         4
# 17        18             On Nut  13.705611  100.601083         5
# 18        19          Bang Chak  13.696751  100.605349         6
# 19        20         Punnawithi  13.688919  100.609211         7
# 20        21           Udom Suk  13.680317  100.609658         8
# 21        22            Bang Na  13.668146  100.604703         9
# 22        23            Bearing  13.659336  100.601050        10
# 23        24            Samrong  13.647363  100.596153        11
# 24        25            Pu Chao  13.637280  100.592000        12
#
#     Cluster Labels 1st Most Common Venue 2nd Most Common Venue  \
# 0                1           Coffee Shop                   Bar
# 1                1           Coffee Shop       Thai Restaurant
# 2                1       Thai Restaurant           Coffee Shop
# 3                4       Thai Restaurant           Coffee Shop
# 4                1          Noodle House           Coffee Shop
# 5                0                 Hotel          Noodle House
# 6                0                 Hotel          Noodle House
# 7                0                 Hotel           Coffee Shop
# 8                1           Coffee Shop          Dessert Shop
# 9                0                 Hotel           Coffee Shop
# 10               0                 Hotel           Coffee Shop
# 11               0                 Hotel     Korean Restaurant
# 12               0                 Hotel     Korean Restaurant
# 13               4   Japanese Restaurant                  Café
# 14               4       Thai Restaurant           Coffee Shop
# 15               4   Japanese Restaurant           Coffee Shop
# 16               4           Coffee Shop   Japanese Restaurant
# 17               2     Convenience Store                 Hotel
# 18               2     Convenience Store          Noodle House
# 19               2     Convenience Store       Thai Restaurant
# 20               2       Thai Restaurant     Convenience Store
# 21               1           Coffee Shop     Convenience Store
# 22               2     Convenience Store          Noodle House
# 23               2          Noodle House     Convenience Store
# 24               3     Convenience Store          Noodle House
#
#    3rd Most Common Venue 4th Most Common Venue 5th Most Common Venue  \
# 0        
# 13                     Spa        Massage Studio             Restaurant
# 14            Noodle House                   Spa           Cocktail Bar
# 15                   Hotel      Ramen Restaurant             Theme Park
# 16        Ramen Restaurant           Art Gallery        Thai Restaurant
# 17          Ice Cream Shop    Chinese Restaurant                   Café
# 18           Train Station                   Spa                 Market
# 19                    Café                 Hotel            Gas Station
# 20                  Bakery    Dim Sum Restaurant              BBQ Joint
# 21             Music Venue               Stadium     Golf Driving Range
# 22                Bus Stop      Asian Restaurant                 Bakery
# 23  Shabu-Shabu Restaurant                Buffet         Medical Center
# 24            Soccer Field                  Café                 Museum

# %% [markdown]
# ## Display Cluster on the Map

# %%
# Create map
map_clusters = folium.Map(location=[latitude, longitude], zoom_start=11)

# Set color scheme for the clusters
x = np.arange(kclusters)
ys = [i + x + (i*x)**2 for i in range(kclusters)]
colors_array = cm.rainbow(np.linspace(0, 1, len(ys)))
rainbow = [colors.rgb2hex(i) for i in colors_array]

# Add markers to the map
markers_colors = []
for lat, lon, poi, cluster in zip(station_merged['Latitude'], station_merged['Longitude'], station_merged['Station Name'], station_merged['Cluster Labels']):
    label = folium.Popup(str(poi) + ' Cluster ' + str(cluster), parse_html=True)
    folium.CircleMarker(
        [lat, lon],
        radius=5,
        popup=label,
        color=rainbow[cluster-1],
        fill=True,
        fill_color=rainbow[cluster-1],
        fill_opacity=0.7).add_to(map_clusters)
       
map_clusters
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# ## Examime each cluster

# %% [markdown]
# ### Cluster Labels = 0

# %%
station_merged.loc[station_merged['Cluster Labels'] == 0, station_merged.columns[[1] + list(range(5, station_merged.shape[1]))]]
# Out:
#         Station Name  Cluster Labels 1st Most Common Venue  \
# 5   Victory Monument               0                 Hotel
# 6         Phaya Thai               0                 Hotel
# 7        Ratchathewi               0                 Hotel
# 9           Chit Lom               0                 Hotel
# 10       Phloen Chit               0                 Hotel
# 11              Nana               0                 Hotel
# 12              Asok               0                 Hotel
#
#    2nd Most Common Venue 3rd Most Common Venue 4th Most Common Venue  \
# 5           Noodle House           Coffee Shop                  Café
# 6           Noodle House           Coffee Shop                Hostel
# 7            Coffee Shop                Hostel          Dessert Shop
# 9            Coffee Shop       Thai Restaurant                   Spa
# 10           Coffee Shop                  Café       Thai Restaurant
# 11     Korean Restaurant             Hotel Bar     Indian Restaurant
# 12     Korean Restaurant           Coffee Shop       Thai Restaurant
#
#    5th Most Common Venue 6th Most Common Venue 7th Most Common Venue  \
# 5             Steakhouse       Thai Restaurant                Hostel
# 6             Steakhouse                  Café            Restaurant
# 7                 Bakery                  Café            Restaurant
# 9     Chinese Restaurant        Ice Cream Shop    Italian Restaurant
# 10            Restaurant             Hotel Bar     French Restaurant
# 11   Japanese Restaurant           Coffee Shop           Pizza Place
# 12                   Spa            Restaurant             Hotel Bar
#
#    8th Most Common Venue 9th Most Common Venue 10th Most Common Venue
# 5      Convenience Store                Bakery             Food Court
# 6     Som Tum Restaurant     Convenience Store                    Bar
# 7          Shopping Mall     Korean Restaurant                    Bar
# 9       Department Store            Restaurant         Cosmetics Shop
# 10   Japanese Restaurant    Italian Restaurant                 Buffet
# 11                   Spa                  Café                    Bar
# 12          Burger Joint                  Café              BBQ Joint

# %% [markdown]
# ### Cluster Labels = 1

# %%
station_merged.loc[station_merged['Cluster Labels'] == 1, station_merged.columns[[1] + list(range(5, station_merged.shape[1]))]]
# Out:
#          Station Name  Cluster Labels 1st Most Common Venue  \
# 0   Ha Yaek Lat Phrao               1           Coffee Shop
# 1             Mo Chit               1           Coffee Shop
# 2        Saphan Khwai               1       Thai Restaurant
# 4           Sanam Pao               1          Noodle House
# 8                Siam               1           Coffee Shop
# 21            Bang Na               1           Coffee Shop
#
#    2nd Most Common Venue 3rd Most Common Venue 4th Most Common Venue  \
# 0                    Bar       Thai Restaurant          Dessert Shop
# 1        Thai Restaurant     Convenience Store                  Café
# 2            Coffee Shop          Noodle House    Som Tum Restaurant
# 4            Coffee Shop       Thai Restaurant      Sushi Restaurant
# 8           Dessert Shop                Bakery                  Café
# 21     Convenience Store  Fast Food Restaurant          Noodle House
#
#    5th Most Common Venue 6th Most Common Venue 7th Most Common Venue  \
# 0         Ice Cream Shop   Japanese Restaurant     Korean Restaurant
# 1           Noodle House         Shopping Mall    Som Tum Restaurant
# 2                   Café     Convenience Store                 Hotel
# 4                    Bar            Restaurant                Bakery
# 8        Thai Restaurant         Shopping Mall     Korean Restaurant
# 21         Train Station       Thai Restaurant     Hotpot Restaurant
#
#    8th Most Common Venue 9th Most Common Venue 10th Most Common Venue
# 0         Clothing Store                Bakery              Bookstore
# 1     Seafood Restaurant                  Park   Fast Food Restaurant
# 2     Seafood Restaurant                   Bar              BBQ Joint
# 4                  Hotel             BBQ Joint                   Café
# 8          Movie Theater        Cosmetics Shop               Boutique
# 21           Music Venue               Stadium     Golf Driving Range

# %% [markdown]
# ### Cluster Labels = 2

# %%
station_merged.loc[station_merged['Cluster Labels'] == 2, station_merged.columns[[1] + list(range(5, station_merged.shape[1]))]]
# Out:
#    Station Name  Cluster Labels 1st Most Common Venue 2nd Most Common Venue  \
# 17       On Nut               2     Convenience Store                 Hotel
# 18    Bang Chak               2     Convenience Store          Noodle House
# 19   Punnawithi               2     Convenience Store       Thai Restaurant
# 20     Udom Suk               2       Thai Restaurant     Convenience Store
# 22      Bearing               2     Convenience Store          Noodle House
# 23      Samrong               2          Noodle House     Convenience Store
#
#    3rd Most Common Venue 4th Most Common Venue 5th Most Common Venue  \
# 17           Coffee Shop    Italian Restaurant  Fast Food Restaurant
# 18           Coffee Shop    Chinese Restaurant                 Hotel
# 19  Fast Food Restaurant           Coffee Shop          Noodle House
# 20          Noodle House  Fast Food Restaurant                  Café
# 22           Coffee Shop       Thai Restaurant                  Café
# 23  Fast Food Restaurant                Market     Hotpot Restaurant
#
#                        6th Most Common Venue 7th Most Common Venue  \
# 17  Residential Building (Apartment / Condo)          Noodle House
# 18                           Thai Restaurant    Italian Restaurant
# 19                            Ice Cream Shop                Bakery
# 20                               Coffee Shop                   Bar
# 22                                Steakhouse                Market
# 23                          Ramen Restaurant                Bakery
#
#      8th Most Common Venue 9th Most Common Venue 10th Most Common Venue
# 17          Ice Cream Shop    Chinese Restaurant                   Café
# 18           Train Station                   Spa                 Market
# 19                    Café                 Hotel            Gas Station
# 20                  Bakery    Dim Sum Restaurant              BBQ Joint
# 22                Bus Stop      Asian Restaurant                 Bakery
# 23  Shabu-Shabu Restaurant                Buffet         Medical Center

# %% [markdown]
# ### Cluster Labels = 3

# %%
station_merged.loc[station_merged['Cluster Labels'] == 3, station_merged.columns[[1] + list(range(5, station_merged.shape[1]))]]
# Out:
#    Station Name  Cluster Labels 1st Most Common Venue 2nd Most Common Venue  \
# 24      Pu Chao               3     Convenience Store          Noodle House
#
#    3rd Most Common Venue 4th Most Common Venue 5th Most Common Venue  \
# 24            Food Truck          Intersection             BBQ Joint
#
#    6th Most Common Venue 7th Most Common Venue 8th Most Common Venue  \
# 24           Bus Station              Bus Stop          Soccer Field
#
#    9th Most Common Venue 10th Most Common Venue
# 24                  Café                 Museum

# %% [markdown]
# ### Cluster Labels = 4

# %%
station_merged.loc[station_merged['Cluster Labels'] == 4, station_merged.columns[[1] + list(range(5, station_merged.shape[1]))]]
# Out:
#     Station Name  Cluster Labels 1st Most Common Venue 2nd Most Common Venue  \
# 3            Ari               4       Thai Restaurant           Coffee Shop
# 13   Phrom Phong               4   Japanese Restaurant                  Café
# 14      Thong Lo               4       Thai Restaurant           Coffee Shop
# 15       Ekkamai               4   Japanese Restaurant           Coffee Shop
# 16  Phra Khanong               4           Coffee Shop   Japanese Restaurant
#
#    3rd Most Common Venue 4th Most Common Venue 5th Most Common Venue  \
# 3                   Café          Noodle House                   Bar
# 13                 Hotel           Coffee Shop       Thai Restaurant
# 14   Japanese Restaurant                  Café                 Hotel
# 15       Thai Restaurant                  Café          Dessert Shop
# 16     Convenience Store  Gym / Fitness Center          Noodle House
#
#    6th Most Common Venue 7th Most Common Venue 8th Most Common Venue  \
# 3       Sushi Restaurant    Som Tum Restaurant            Restaurant
# 13           Supermarket         Shopping Mall                   Spa
# 14             BBQ Joint                   Bar          Noodle House
# 15          Noodle House  Gym / Fitness Center                 Hotel
# 16                Bakery                  Café      Ramen Restaurant
#
#    9th Most Common Venue 10th Most Common Venue
# 3    Japanese Restaurant              BBQ Joint
# 13        Massage Studio             Restaurant
# 14                   Spa           Cocktail Bar
# 15      Ramen Restaurant             Theme Park
# 16           Art Gallery        Thai Restaurant

# %% [markdown]
# # Examine Living Expenses based on price tier of sample venues
# Venues' details return from FourSquare contain info of price tier but not all of venues have this price tier info

# %%
# Merge Dataframes
venues_merged = station_venues.join(station_sorted[['Station Name','Cluster Labels']].set_index('Station Name'), on='Station Name')
venues_merged
# Out:
#            Station Name  Station Latitude  Station Longitude  \
# 0     Ha Yaek Lat Phrao         13.816552         100.562012
# 1     Ha Yaek Lat Phrao         13.816552         100.562012
# 2     Ha Yaek Lat Phrao         13.816552         100.562012
# 3     Ha Yaek Lat Phrao         13.816552         100.562012
# 4     Ha Yaek Lat Phrao         13.816552         100.562012
# ...                 ...               ...                ...
# 2150            Pu Chao         13.637280         100.592000
# 2151            Pu Chao         13.637280         100.592000
# 2152            Pu Chao         13.637280         100.592000
# 2153            Pu Chao         13.637280         100.592000
# 2154            Pu Chao         13.637280         100.592000
#
#                       Venue ID  \
# 0     4c26d6e05c5ca593ebfa46fe
# 1     4b9a45d6f964a520d2a835e3
# 2     4f338c37e4b0662777593023
# 3     4e59ed36d164da2b2769fcc2
# 4     4b0bc026f964a520663323e3
# ...                        ...
# 2150  50416ff7e4b0b5223da49e85
# 2151  4d99ca67647d8cfa148a0f3e
# 2152  4ce25a2c7e2e236ab820951b
# 2153  4eccb7030aafc14745e69c13
# 2154  4f4cb0b3e4b0f0c7003d30db
#
#                                                Venue  Venue Latitude  \
# 0                             Starbucks (สตาร์บัคส์)       13.817346
# 1                             Starbucks (สตาร์บัคส์)       13.816479
# 2                            After You (อาฟเตอร์ ยู)       13.816114
# 3          Cold Stone Creamery (โคล สโตน ครีมเมอรี่)       13.816303
# 4     CentralPlaza Lardprao (เซ็นทรัลพลาซา ลาดพร้าว)       13.816376
# ...                                              ...             ...
# 2150                  ร้านข้าวมันไก่ตอน (ปอ)เจ้าเก่า       13.643967
# 2151                    Club 148 สนามฟุตบอลหญ้าเทียม       13.643647
# 2152         The Pizza Company (เดอะ พิซซ่า คอมปะนี)       13.644400
# 2153           Pak Nam 2 Toll Plaza (ด่านฯ ปากน้ำ 2)       13.628549
# 2154                                ตลาดนัดรุ่งเจริญ       13.644611
#
#       Venue Longitude    Venue Category  Cluster Labels
# 0          100.561466       Coffee Shop               1
# 1          100.560947       Coffee Shop               1
# 2          100.560331      Dessert Shop               1
# 3          100.560715    Ice Cream Shop               1
# 4          100.561057     Shopping Mall               1
# ...               ...               ...             ...
# 2150       100.588624  Asian Restaurant               3
# 2151       100.597727      Soccer Field               3
# 2152       100.587137       Pizza Place               3
# 2153       100.592792        Toll Plaza               3
# 2154       100.586750       Flea Market               3
#
# [2155 rows x 9 columns]

# %%
# Function to get price tier from sample venues for each cluster
def get_price_tier(df,cluster,n):
    sample = df.loc[df['Cluster Labels'] == cluster].sample(n)
    price_tier_array = []
    for id in sample['Venue ID']:
        url = 'https://api.foursquare.com/v2/venues/{}?client_id={}&client_secret={}&v={}'.format(id, CLIENT_ID, CLIENT_SECRET, VERSION)
        result = requests.get(url).json()
        try:
            price_tier_array.append(result['response']['venue']['price']['tier'])
        except:
            pass
    return np.mean(price_tier_array)

# %%
# Analysis price tier from sample for each cluster
data = []
n = 30
for cluster in range(kclusters):
    price_tier = get_price_tier(venues_merged,cluster,n)
    data.append([cluster, price_tier])

# %%
# Create Dataframe Price Tier for each Cluster
dfPriceTier = pd.DataFrame(data, columns = ['Cluster Labels','Price Tier'])
dfPriceTier
# Out:
#    Cluster Labels  Price Tier
# 0               0    2.733333
# 1               1    2.105263
# 2               2    2.000000
# 3               3    1.800000
# 4               4    2.050000

# %% [markdown]
# ## Results
# Based on above results, the lowest living expenses cluster is Cluster Labels 3 and the 2nd lowest living expenses cluster is Cluster Labels 2 (Depicted below on the maps)

# %%
# Create map
map_results = folium.Map(location=[latitude, longitude], zoom_start=11)
c2 = station_merged.loc[station_merged['Cluster Labels'] == 2]
c3 = station_merged.loc[station_merged['Cluster Labels'] == 3]
results = pd.concat([c3,c2])

# Set color scheme for the clusters
x = np.arange(kclusters)
ys = [i + x + (i*x)**2 for i in range(kclusters)]
colors_array = cm.rainbow(np.linspace(0, 1, len(ys)))
rainbow = [colors.rgb2hex(i) for i in colors_array]

# Add markers to the map
markers_colors = []
for lat, lon, poi, cluster in zip(results['Latitude'], results['Longitude'], results['Station Name'], results['Cluster Labels']):
    label = folium.Popup(str(poi) + ' Cluster ' + str(cluster), parse_html=True)
    folium.CircleMarker(
        [lat, lon],
        radius=5,
        popup=label,
        color=rainbow[cluster-1],
        fill=True,
        fill_color=rainbow[cluster-1],
        fill_opacity=0.7).add_to(map_results)
       
map_results
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
results
# Out:
#     Sequence Station Name   Latitude   Longitude  Distance  Cluster Labels  \
# 24        25      Pu Chao  13.637280  100.592000        12               3
# 17        18       On Nut  13.705611  100.601083         5               2
# 18        19    Bang Chak  13.696751  100.605349         6               2
# 19        20   Punnawithi  13.688919  100.609211         7               2
# 20        21     Udom Suk  13.680317  100.609658         8               2
# 22        23      Bearing  13.659336  100.601050        10               2
# 23        24      Samrong  13.647363  100.596153        11               2
#
#    1st Most Common Venue 2nd Most Common Venue 3rd Most Common Venue  \
# 24     Convenience Store          Noodle House            Food Truck
# 17     Convenience Store                 Hotel           Coffee Shop
# 18     Convenience Store          Noodle House           Coffee Shop
# 19     Convenience Store       Thai Restaurant  Fast Food Restaurant
# 20       Thai Restaurant     Convenience Store          Noodle House
# 22     Convenience Store          Noodle House           Coffee Shop
# 23          Noodle House     Convenience Store  Fast Food Restaurant
#
#    4th Most Common Venue 5th Most Common Venue  \
# 24          Intersection             BBQ Joint
# 17    Italian Restaurant  Fast Food Restaurant
# 18    Chinese Restaurant                 Hotel
# 19           Coffee Shop          Noodle House
# 20  Fast Food Restaurant                  Café
# 22       Thai Restaurant                  Café
# 23                Market     Hotpot Restaurant
#
#                        6th Most Common Venue 7th Most Common Venue  \
# 24                               Bus Station              Bus Stop
# 17  Residential Building (Apartment / Condo)          Noodle House
# 18                           Thai Restaurant    Italian Restaurant
# 19                            Ice Cream Shop                Bakery
# 20                               Coffee Shop                   Bar
# 22                                Steakhouse                Market
# 23                          Ramen Restaurant                Bakery
#
#      8th Most Common Venue 9th Most Common Venue 10th Most Common Venue
# 24            Soccer Field                  Café                 Museum
# 17          Ice Cream Shop    Chinese Restaurant                   Café
# 18           Train Station                   Spa                 Market
# 19                    Café                 Hotel            Gas Station
# 20                  Bakery    Dim Sum Restaurant              BBQ Joint
# 22                Bus Stop      Asian Restaurant                 Bakery
# 23  Shabu-Shabu Restaurant                Buffet         Medical Center
